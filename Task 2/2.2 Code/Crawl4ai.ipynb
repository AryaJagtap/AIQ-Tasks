# %%
import asyncio
from crawl4ai import AsyncWebCrawler
import json

async def main():
    async with AsyncWebCrawler() as crawler:
        # Replace with any RailYatri train URL
        url = "https://www.railyatri.in/trains/12951-mumbai-ltt-hyderabad-safal-express"

        # Crawl the page
        result = await crawler.arun(url=url)

        # Extract tables (Crawl4AI auto-detects tables)
        tables = result.tables

        if tables:
            # Save the first table as JSON
            with open("train_schedule.json", "w", encoding="utf-8") as f:
                json.dump(tables[0], f, indent=2, ensure_ascii=False)
            print(" Train schedule saved to train_schedule.json")
        else:
            print(" No tables found on the page.")

        # Optional: print table
        print(tables[0] if tables else "No table found.")

# Run the crawler
await main()
# Out:
# [INIT].... → Crawl4AI 0.7.7
# [FETCH]... ↓ https://www.railyatri.in/trains/12951-mumbai-ltt-hyderabad-safal-express                             |
# ✓ | ⏱: 2.11s
# [SCRAPE].. ◆ https://www.railyatri.in/trains/12951-mumbai-ltt-hyderabad-safal-express                             |
# ✓ | ⏱: 0.09s
# [COMPLETE] ● https://www.railyatri.in/trains/12951-mumbai-ltt-hyderabad-safal-express                             |
# ✓ | ⏱: 2.21s
#  Train schedule saved to train_schedule.json
# {'headers': ['Train Number', 'Train Name', 'Starts', 'Ends'], 'rows': [['58719', 'Abhanpur Rajim Pasenger', 'Abhanpur Junction', 'Rajim'], ['58721', 'Abhanpur Rajim Pasenger', 'Abhanpur Junction', 'Rajim'], ['18242', 'Abkp Durg Exp', 'Ambikapur', 'Durg'], ['18756', 'Abkp Sdl Exp', 'Ambikapur', 'Shahdol'], ['14722', 'Abohar Jodhpur Expres', 'Abohar', 'Jodhpur Jn'], ['79438', 'Abu Road Mahesana Demu', 'Abu Road', 'Mahesana Jn'], ['22214', 'Ac Duronto Expres', 'Patna Jn', 'Kolkata Shalimar'], ['55338', 'Achnera Kasganj Fast Pasenger', 'Achnera Jn', 'Kasganj'], ['05348', 'Achnera Kasganj Pasenger Special', 'Achnera Jn', 'Kasganj'], ['07681', 'Adb Mas Rrb Spl', 'Adilabad', 'Mgr Chenai Central'], ['04166', 'Adi Agc Sup Spl', 'Ahmedabad Jn', 'Agra Cant'], ['09089', 'Adi Gkp Spl', 'Ahmedabad Jn', 'Gorakhpur Jn'], ['09410', 'Adi Heritage Spl', 'Ekta Nagar', 'Ahmedabad Jn'], ['09429', 'Adi Mfp Spl', 'Ahmedabad Jn', 'Muzafarpur Jn'], ['57554', 'Adilabad Parli Vaijnath Pasenger', 'Adilabad', 'Parli Vaijnath'], ['07775', 'Adilabad Parli Vaijnath Special (Un Reserved)', 'Adilabad', 'Parli Vaijnath'], ['57552', 'Adilabad Purna Pasenger', 'Adilabad', 'Purna Jn'], ['68063', 'Adra Asansol Memu', 'Adra Jn', 'Asansol Jn'], ['68045', 'Adra Asansol Memu', 'Adra Jn', 'Asansol Jn'], ['68061', 'Adra Asansol Memu', 'Adra Jn', 'Asansol Jn']], 'caption': '', 'summary': '', 'metadata': {'row_count': 20, 'column_count': 4, 'has_headers': True, 'has_caption': False, 'has_summary': False, 'class': 'table train-dir-tbl'}}

# %%
import asyncio
from crawl4ai import AsyncWebCrawler
import pandas as pd

# List of RailYatri train URLs (replace with the trains you want)
train_urls = [
    "https://www.railyatri.in/trains/12951-mumbai-ltt-hyderabad-safal-express",
    "https://www.railyatri.in/trains/12723-delhi-hyderabad-hamsafar-express"
]

async def main():
    all_trains_data = []

    async with AsyncWebCrawler() as crawler:
        for url in train_urls:
            print(f"🚀 Crawling {url} ...")
            result = await crawler.arun(url=url)

            # Crawl4AI auto-detects tables
            tables = result.tables

            if tables:
                # Take the first table (usually schedule) which is a dictionary
                table_data = tables[0]
                headers = table_data.get('headers', [])
                rows = table_data.get('rows', [])

                for list_row in rows:
                    # Convert the list row to a dictionary using headers
                    dict_row = dict(zip(headers, list_row))
                    dict_row['train_url'] = url
                    all_trains_data.append(dict_row)
            else:
                print(f" No table found for {url}")

    # Convert all data to DataFrame
    df = pd.DataFrame(all_trains_data)

    # Save to CSV
    df.to_csv("train_schedules.csv", index=False, encoding="utf-8")
    print("All train schedules saved to train_schedules.csv")

# Run crawler
await main()
# Out:
# [INIT].... → Crawl4AI 0.7.7
# 🚀 Crawling https://www.railyatri.in/trains/12951-mumbai-ltt-hyderabad-safal-express ...
# [FETCH]... ↓ https://www.railyatri.in/trains/12951-mumbai-ltt-hyderabad-safal-express                             |
# ✓ | ⏱: 2.39s
# [SCRAPE].. ◆ https://www.railyatri.in/trains/12951-mumbai-ltt-hyderabad-safal-express                             |
# ✓ | ⏱: 0.17s
# [COMPLETE] ● https://www.railyatri.in/trains/12951-mumbai-ltt-hyderabad-safal-express                             |
# ✓ | ⏱: 2.58s
# 🚀 Crawling https://www.railyatri.in/trains/12723-delhi-hyderabad-hamsafar-express ...
# [FETCH]... ↓ https://www.railyatri.in/trains/12723-delhi-hyderabad-hamsafar-express                               |
# ✓ | ⏱: 4.06s
# [SCRAPE].. ◆ https://www.railyatri.in/trains/12723-delhi-hyderabad-hamsafar-express                               |
# ✓ | ⏱: 0.08s
# [COMPLETE] ● https://www.railyatri.in/trains/12723-delhi-hyderabad-hamsafar-express                               |
# ✓ | ⏱: 4.15s
# All train schedules saved to train_schedules.csv

# %%
import pandas as pd

df_schedules = pd.read_csv('train_schedules.csv')
display(df_schedules)
# Out:
#     Train Number                                     Train Name  \
# 0          58719                        Abhanpur Rajim Pasenger
# 1          58721                        Abhanpur Rajim Pasenger
# 2          18242                                  Abkp Durg Exp
# 3          18756                                   Abkp Sdl Exp
# 4          14722                          Abohar Jodhpur Expres
# 5          79438                         Abu Road Mahesana Demu
# 6          22214                              Ac Duronto Expres
# 7          55338                  Achnera Kasganj Fast Pasenger
# 8           5348               Achnera Kasganj Pasenger Special
# 9           7681                                Adb Mas Rrb Spl
# 10          4166                                Adi Agc Sup Spl
# 11          9089                                    Adi Gkp Spl
# 12          9410                               Adi Heritage Spl
# 13          9429                                    Adi Mfp Spl
# 14         57554               Adilabad Parli Vaijnath Pasenger
# 15          7775  Adilabad Parli Vaijnath Special (Un Reserved)
# 16         57552                        Adilabad Purna Pasenger
# 17         68063                              Adra Asansol Memu
# 18         68045                              Adra Asansol Memu
# 19         68061                              Adra Asansol Memu
# 20         58719                        Abhanpur Rajim Pasenger
# 21         58721                        Abhanpur Rajim Pasenger
# 22         18242                                  Abkp Durg Exp
# 23         18756                                   Abkp Sdl Exp
# 24         14722                          Abohar Jodhpur Expres
# 25         79438                         Abu Road Mahesana Demu
# 26         22214                              Ac Duronto Expres
# 27         55338                  Achnera Kasganj Fast Pasenger
# 28          5348               Achnera Kasganj Pasenger Special
# 29          7681                                Adb Mas Rrb Spl
# 30          4166                                Adi Agc Sup Spl
# 31          9089                                    Adi Gkp Spl
# 32          9410                               Adi Heritage Spl
# 33          9429                                    Adi Mfp Spl
# 34         57554               Adilabad Parli Vaijnath Pasenger
# 35          7775  Adilabad Parli Vaijnath Special (Un Reserved)
# 36         57552                        Adilabad Purna Pasenger
# 37         68063                              Adra Asansol Memu
# 38         68045                              Adra Asansol Memu
# 39         68061                              Adra Asansol Memu
#
#                Starts                Ends  \
# 0   Abhanpur Junction               Rajim
# 1   Abhanpur Junction               Rajim
# 2           Ambikapur                Durg
# 3           Ambikapur             Shahdol
# 4              Abohar          Jodhpur Jn
# 5            Abu Road         Mahesana Jn
# 6            Patna Jn    Kolkata Shalimar
# 7          Achnera Jn             Kasganj
# 8          Achnera Jn             Kasganj
# 9            Adilabad  Mgr Chenai Central
# 10       Ahmedabad Jn           Agra Cant
# 11       Ahmedabad Jn        Gorakhpur Jn
# 12         Ekta Nagar        Ahmedabad Jn
# 13       Ahmedabad Jn       Muzafarpur Jn
# 14           Adilabad      Parli Vaijnath
# 15           Adilabad      Parli Vaijnath
# 16           Adilabad            Purna Jn
# 17            Adra Jn          Asansol Jn
# 18            Adra Jn          Asansol Jn
# 19            Adra Jn          Asansol Jn
# 20  Abhanpur Junction               Rajim
# 21  Abhanpur Junction               Rajim
# 22          Ambikapur                Durg
# 23          Ambikapur             Shahdol
# 24             Abohar          Jodhpur Jn
# 25           Abu Road         Mahesana Jn
# 26           Patna Jn    Kolkata Shalimar
# 27         Achnera Jn             Kasganj
# 28         Achnera Jn             Kasganj
# 29           Adilabad  Mgr Chenai Central
# 30       Ahmedabad Jn           Agra Cant
# 31       Ahmedabad Jn        Gorakhpur Jn
# 32         Ekta Nagar        Ahmedabad Jn
# 33       Ahmedabad Jn       Muzafarpur Jn
# 34           Adilabad      Parli Vaijnath
# 35           Adilabad      Parli Vaijnath
# 36           Adilabad            Purna Jn
# 37            Adra Jn          Asansol Jn
# 38            Adra Jn          Asansol Jn
# 39            Adra Jn          Asansol Jn
#
#                                             train_url
# 0   https://www.railyatri.in/trains/12951-mumbai-l...
# 1   https://www.railyatri.in/trains/12951-mumbai-l...
# 2   https://www.railyatri.in/trains/12951-mumbai-l...
# 3   https://www.railyatri.in/trains/12951-mumbai-l...
# 4   https://www.railyatri.in/trains/12951-mumbai-l...
# 5   https://www.railyatri.in/trains/12951-mumbai-l...
# 6   https://www.railyatri.in/trains/12951-mumbai-l...
# 7   https://www.railyatri.in/trains/12951-mumbai-l...
# 8   https://www.railyatri.in/trains/12951-mumbai-l...
# 9   https://www.railyatri.in/trains/12951-mumbai-l...
# 10  https://www.railyatri.in/trains/12951-mumbai-l...
# 11  https://www.railyatri.in/trains/12951-mumbai-l...
# 12  https://www.railyatri.in/trains/12951-mumbai-l...
# 13  https://www.railyatri.in/trains/12951-mumbai-l...
# 14  https://www.railyatri.in/trains/12951-mumbai-l...
# 15  https://www.railyatri.in/trains/12951-mumbai-l...
# 16  https://www.railyatri.in/trains/12951-mumbai-l...
# 17  https://www.railyatri.in/trains/12951-mumbai-l...
# 18  https://www.railyatri.in/trains/12951-mumbai-l...
# 19  https://www.railyatri.in/trains/12951-mumbai-l...
# 20  https://www.railyatri.in/trains/12723-delhi-hy...
# 21  https://www.railyatri.in/trains/12723-delhi-hy...
# 22  https://www.railyatri.in/trains/12723-delhi-hy...
# 23  https://www.railyatri.in/trains/12723-delhi-hy...
# 24  https://www.railyatri.in/trains/12723-delhi-hy...
# 25  https://www.railyatri.in/trains/12723-delhi-hy...
# 26  https://www.railyatri.in/trains/12723-delhi-hy...
# 27  https://www.railyatri.in/trains/12723-delhi-hy...
# 28  https://www.railyatri.in/trains/12723-delhi-hy...
# 29  https://www.railyatri.in/trains/12723-delhi-hy...
# 30  https://www.railyatri.in/trains/12723-delhi-hy...
# 31  https://www.railyatri.in/trains/12723-delhi-hy...
# 32  https://www.railyatri.in/trains/12723-delhi-hy...
# 33  https://www.railyatri.in/trains/12723-delhi-hy...
# 34  https://www.railyatri.in/trains/12723-delhi-hy...
# 35  https://www.railyatri.in/trains/12723-delhi-hy...
# 36  https://www.railyatri.in/trains/12723-delhi-hy...
# 37  https://www.railyatri.in/trains/12723-delhi-hy...
# 38  https://www.railyatri.in/trains/12723-delhi-hy...
# 39  https://www.railyatri.in/trains/12723-delhi-hy...

# %%
import asyncio
from crawl4ai import AsyncWebCrawler
import pandas as pd

# List of RailYatri train URLs
train_urls = [
    "https://www.railyatri.in/trains/12951-mumbai-ltt-hyderabad-safal-express",
    "https://www.railyatri.in/trains/12723-delhi-hyderabad-hamsafar-express"
]

async def main():
    all_data = []

    async with AsyncWebCrawler() as crawler:
        for url in train_urls:
            print(f" Crawling {url} ...")
            result = await crawler.arun(url=url)

            # Crawl4AI auto-detects tables
            tables = result.tables
            if not tables:
                print(f"No tables found for {url}")
                continue

            # Usually first table = schedule
            # The table is a dictionary with 'headers' and 'rows'
            schedule_table_data = tables[0]
            headers = schedule_table_data.get('headers', [])
            rows = schedule_table_data.get('rows', [])

            # Optional: extract running status / seat info from other tables
            running_status = "N/A"
            seat_availability = "N/A"

            # Assuming table 1 (tables[1]) might contain seat info
            if len(tables) > 1 and tables[1]:
                seat_info_table = tables[1]
                # Check if seat_info_table is also a dictionary with 'headers' and 'rows'
                if isinstance(seat_info_table, dict) and 'rows' in seat_info_table:
                    seat_headers = seat_info_table.get('headers', [])
                    seat_rows = seat_info_table.get('rows', [])

                    seat_availability_parts = []
                    for seat_list_row in seat_rows:
                        seat_dict_row = dict(zip(seat_headers, seat_list_row))
                        # Assuming 'Class' and 'Availability' are keys in seat_dict_row
                        seat_availability_parts.append(f"{seat_dict_row.get('Class','')}:{seat_dict_row.get('Availability','')}")
                    seat_availability = "; ".join(seat_availability_parts)

            # Process each actual data row
            for list_row in rows:
                # Convert the list row to a dictionary using headers
                dict_row = dict(zip(headers, list_row))
                dict_row['train_url'] = url
                dict_row['running_status'] = running_status
                dict_row['seat_availability'] = seat_availability
                all_data.append(dict_row)

    # Convert to DataFrame
    df = pd.DataFrame(all_data)

    # Save to CSV
    df.to_csv("train_full_data.csv", index=False, encoding="utf-8")
    print(" All train data saved to train_full_data.csv")

# Run crawler
await main()
# Out:
# [INIT].... → Crawl4AI 0.7.7
#  Crawling https://www.railyatri.in/trains/12951-mumbai-ltt-hyderabad-safal-express ...
# [FETCH]... ↓ https://www.railyatri.in/trains/12951-mumbai-ltt-hyderabad-safal-express                             |
# ✓ | ⏱: 3.28s
# [SCRAPE].. ◆ https://www.railyatri.in/trains/12951-mumbai-ltt-hyderabad-safal-express                             |
# ✓ | ⏱: 0.18s
# [COMPLETE] ● https://www.railyatri.in/trains/12951-mumbai-ltt-hyderabad-safal-express                             |
# ✓ | ⏱: 3.48s
#  Crawling https://www.railyatri.in/trains/12723-delhi-hyderabad-hamsafar-express ...
# [FETCH]... ↓ https://www.railyatri.in/trains/12723-delhi-hyderabad-hamsafar-express                               |
# ✓ | ⏱: 4.29s
# [SCRAPE].. ◆ https://www.railyatri.in/trains/12723-delhi-hyderabad-hamsafar-express                               |
# ✓ | ⏱: 0.11s
# [COMPLETE] ● https://www.railyatri.in/trains/12723-delhi-hyderabad-hamsafar-express                               |
# ✓ | ⏱: 4.42s
#  All train data saved to train_full_data.csv

# %%
import asyncio
from crawl4ai import AsyncWebCrawler
import json

async def inspect_tables():
    async with AsyncWebCrawler() as crawler:
        # Use one of the URLs from the previous list for inspection
        url = "https://www.railyatri.in/trains/12951-mumbai-ltt-hyderabad-safal-express"
        print(f" Inspecting tables for {url} ...")
        result = await crawler.arun(url=url)
        tables = result.tables

        if tables:
            print(f"Found {len(tables)} tables.")
            for i, table in enumerate(tables):
                print(f"\n--- Table {i} ---")
                print(json.dumps(table, indent=2, ensure_ascii=False))
        else:
            print("No tables found on the page.")

await inspect_tables()
# Out:
# [INIT].... → Crawl4AI 0.7.7
#  Inspecting tables for https://www.railyatri.in/trains/12951-mumbai-ltt-hyderabad-safal-express ...
# [FETCH]... ↓ https://www.railyatri.in/trains/12951-mumbai-ltt-hyderabad-safal-express                             |
# ✓ | ⏱: 1.92s
# [SCRAPE].. ◆ https://www.railyatri.in/trains/12951-mumbai-ltt-hyderabad-safal-express                             |
# ✓ | ⏱: 0.08s
# [COMPLETE] ● https://www.railyatri.in/trains/12951-mumbai-ltt-hyderabad-safal-express                             |
# ✓ | ⏱: 2.01s
# Found 1 tables.
#
# --- Table 0 ---
# {
#   "headers": [
#     "Train Number",
#     "Train Name",
#     "Starts",
#     "Ends"
#   ],
#   "rows": [
#     [
#       "58719",
#       "Abhanpur Rajim Pasenger",
#       "Abhanpur Junction",
#       "Rajim"
#     ],
#     [
#       "58721",
#       "Abhanpur Rajim Pasenger",
#       "Abhanpur Junction",
#       "Rajim"
#     ],
#     [
#       "18242",
#       "Abkp Durg Exp",
#       "Ambikapur",
#       "Durg"
#     ],
#     [
#       "18756",
#       "Abkp Sdl Exp",
#       "Ambikapur",
#       "Shahdol"
#     ],
#     [
#       "14722",
#       "Abohar Jodhpur Expres",
#       "Abohar",
#       "Jodhpur Jn"
#     ],
#     [
#       "79438",
#       "Abu Road Mahesana Demu",
#       "Abu Road",
#       "Mahesana Jn"
#     ],
#     [
#       "22214",
#       "Ac Duronto Expres",
#       "Patna Jn",
#       "Kolkata Shalimar"
#     ],
#     [
#       "55338",
#       "Achnera Kasganj Fast Pasenger",
#       "Achnera Jn",
#       "Kasganj"
#     ],
#     [
#       "05348",
#       "Achnera Kasganj Pasenger Special",
#       "Achnera Jn",
#       "Kasganj"
#     ],
#     [
#       "07681",
#       "Adb Mas Rrb Spl",
#       "Adilabad",
#       "Mgr Chenai Central"
#     ],
#     [
#       "04166",
#       "Adi Agc Sup Spl",
#       "Ahmedabad Jn",
#       "Agra Cant"
#     ],
#     [
#       "09089",
#       "Adi Gkp Spl",
#       "Ahmedabad Jn",
#       "Gorakhpur Jn"
#     ],
#     [
#       "09410",
#       "Adi Heritage Spl",
#       "Ekta Nagar",
#       "Ahmedabad Jn"
#     ],
#     [
#       "09429",
#       "Adi Mfp Spl",
#       "Ahmedabad Jn",
#       "Muzafarpur Jn"
#     ],
#     [
#       "57554",
#       "Adilabad Parli Vaijnath Pasenger",
#       "Adilabad",
#       "Parli Vaijnath"
#     ],
#     [
#       "07775",
#       "Adilabad Parli Vaijnath Special (Un Reserved)",
#       "Adilabad",
#       "Parli Vaijnath"
#     ],
#     [
#       "57552",
#       "Adilabad Purna Pasenger",
#       "Adilabad",
#       "Purna Jn"
#     ],
#     [
#       "68063",
#       "Adra Asansol Memu",
#       "Adra Jn",
#       "Asansol Jn"
#     ],
#     [
#       "68045",
#       "Adra Asansol Memu",
#       "Adra Jn",
#       "Asansol Jn"
#     ],
#     [
#       "68061",
#       "Adra Asansol Memu",
#       "Adra Jn",
#       "Asansol Jn"
#     ]
#   ],
#   "caption": "",
#   "summary": "",
#   "metadata": {
#     "row_count": 20,
#     "column_count": 4,
#     "has_headers": true,
#     "has_caption": false,
#     "has_summary": false,
#     "class": "table train-dir-tbl"
#   }
# }

# %%
import pandas as pd

df_full_data = pd.read_csv('train_full_data.csv')

print("Column Information for train_full_data.csv:")
df_full_data.info()

print("\nFirst 5 rows of train_full_data.csv:")
display(df_full_data.head())
# Out:
# Column Information for train_full_data.csv:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40 entries, 0 to 39
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Train Number       40 non-null     int64
#  1   Train Name         40 non-null     object
#  2   Starts             40 non-null     object
#  3   Ends               40 non-null     object
#  4   train_url          40 non-null     object
#  5   running_status     0 non-null      float64
#  6   seat_availability  0 non-null      float64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 2.3+ KB
#
# First 5 rows of train_full_data.csv:
#    Train Number               Train Name             Starts        Ends  \
# 0         58719  Abhanpur Rajim Pasenger  Abhanpur Junction       Rajim
# 1         58721  Abhanpur Rajim Pasenger  Abhanpur Junction       Rajim
# 2         18242            Abkp Durg Exp          Ambikapur        Durg
# 3         18756             Abkp Sdl Exp          Ambikapur     Shahdol
# 4         14722    Abohar Jodhpur Expres             Abohar  Jodhpur Jn
#
#                                            train_url  running_status  \
# 0  https://www.railyatri.in/trains/12951-mumbai-l...             NaN
# 1  https://www.railyatri.in/trains/12951-mumbai-l...             NaN
# 2  https://www.railyatri.in/trains/12951-mumbai-l...             NaN
# 3  https://www.railyatri.in/trains/12951-mumbai-l...             NaN
# 4  https://www.railyatri.in/trains/12951-mumbai-l...             NaN
#
#    seat_availability
# 0                NaN
# 1                NaN
# 2                NaN
# 3                NaN
# 4                NaN

# %%
from crawl4ai import AsyncWebCrawler, JsonCssExtractionStrategy
import json

async def scrape_train_schedule():
    # Using a different URL from railyatri.in, which previously worked well
    url = "https://www.railyatri.in/trains/12701-mumbai-hyderabad-deccan-express"

    # Note: For RailYatri, Crawl4AI often auto-detects tables without explicit CSS extractors.
    # However, if specific fields are needed, we can define a JsonCssExtractionStrategy.
    # For now, let's try to get tables directly first.

    async with AsyncWebCrawler() as crawler:
        print(f"🚀 Crawling {url} to get train schedule...")
        result = await crawler.arun(
            url=url,
            # For RailYatri, auto-detection of tables is usually sufficient.
            # We can define an extractor if we need more fine-grained control or other data.
            # extractor=extractor, # Removed for now to rely on auto-detection
            bypass_cache=True,
            goto_options={'timeout': 60000, 'waitUntil': 'domcontentloaded'} # Default or adjusted as needed
        )

        if result.tables:
            print(f"Found {len(result.tables)} tables. Displaying the first one:")
            print(json.dumps(result.tables[0], indent=2, ensure_ascii=False))
        else:
            print("⚠ No tables found on the page for this URL using auto-detection.")

        # If specific content other than tables is needed, result.extracted_content can be used
        # print("\n--- Extracted Content (if any) ---")
        # print(result.extracted_content)

import asyncio
await scrape_train_schedule()
# Out:
# [INIT].... → Crawl4AI 0.7.7
# 🚀 Crawling https://www.railyatri.in/trains/12701-mumbai-hyderabad-deccan-express to get train schedule...
# [FETCH]... ↓ https://www.railyatri.in/trains/12701-mumbai-hyderabad-deccan-express                                |
# ✓ | ⏱: 2.93s
# [SCRAPE].. ◆ https://www.railyatri.in/trains/12701-mumbai-hyderabad-deccan-express                                |
# ✓ | ⏱: 0.18s
# [COMPLETE] ● https://www.railyatri.in/trains/12701-mumbai-hyderabad-deccan-express                                |
# ✓ | ⏱: 3.13s
# Found 1 tables. Displaying the first one:
# {
#   "headers": [
#     "Train Number",
#     "Train Name",
#     "Starts",
#     "Ends"
#   ],
#   "rows": [
#     [
#       "58719",
#       "Abhanpur Rajim Pasenger",
#       "Abhanpur Junction",
#       "Rajim"
#     ],
#     [
#       "58721",
#       "Abhanpur Rajim Pasenger",
#       "Abhanpur Junction",
#       "Rajim"
#     ],
#     [
#       "18242",
#       "Abkp Durg Exp",
#       "Ambikapur",
#       "Durg"
#     ],
#     [
#       "18756",
#       "Abkp Sdl Exp",
#       "Ambikapur",
#       "Shahdol"
#     ],
#     [
#       "14722",
#       "Abohar Jodhpur Expres",
#       "Abohar",
#       "Jodhpur Jn"
#     ],
#     [
#       "79438",
#       "Abu Road Mahesana Demu",
#       "Abu Road",
#       "Mahesana Jn"
#     ],
#     [
#       "22214",
#       "Ac Duronto Expres",
#       "Patna Jn",
#       "Kolkata Shalimar"
#     ],
#     [
#       "55338",
#       "Achnera Kasganj Fast Pasenger",
#       "Achnera Jn",
#       "Kasganj"
#     ],
#     [
#       "05348",
#       "Achnera Kasganj Pasenger Special",
#       "Achnera Jn",
#       "Kasganj"
#     ],
#     [
#       "07681",
#       "Adb Mas Rrb Spl",
#       "Adilabad",
#       "Mgr Chenai Central"
#     ],
#     [
#       "04166",
#       "Adi Agc Sup Spl",
#       "Ahmedabad Jn",
#       "Agra Cant"
#     ],
#     [
#       "09089",
#       "Adi Gkp Spl",
#       "Ahmedabad Jn",
#       "Gorakhpur Jn"
#     ],
#     [
#       "09410",
#       "Adi Heritage Spl",
#       "Ekta Nagar",
#       "Ahmedabad Jn"
#     ],
#     [
#       "09429",
#       "Adi Mfp Spl",
#       "Ahmedabad Jn",
#       "Muzafarpur Jn"
#     ],
#     [
#       "57554",
#       "Adilabad Parli Vaijnath Pasenger",
#       "Adilabad",
#       "Parli Vaijnath"
#     ],
#     [
#       "07775",
#       "Adilabad Parli Vaijnath Special (Un Reserved)",
#       "Adilabad",
#       "Parli Vaijnath"
#     ],
#     [
#       "57552",
#       "Adilabad Purna Pasenger",
#       "Adilabad",
#       "Purna Jn"
#     ],
#     [
#       "68063",
#       "Adra Asansol Memu",
#       "Adra Jn",
#       "Asansol Jn"
#     ],
#     [
#       "68045",
#       "Adra Asansol Memu",
#       "Adra Jn",
#       "Asansol Jn"
#     ],
#     [
#       "68061",
#       "Adra Asansol Memu",
#       "Adra Jn",
#       "Asansol Jn"
#     ]
#   ],
#   "caption": "",
#   "summary": "",
#   "metadata": {
#     "row_count": 20,
#     "column_count": 4,
#     "has_headers": true,
#     "has_caption": false,
#     "has_summary": false,
#     "class": "table train-dir-tbl"
#   }
# }
